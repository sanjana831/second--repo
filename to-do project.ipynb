# %%
user_input = 'random'

while user_input != '4':
    user_input = input('Enter your choice : ')

    if user_input == '1':
        print('Add an item')
    elif user_input == '2':
        print('Mark as done')
    elif user_input == '3':
        print('View the to do items')
    elif user_input == '4':
        print('Goodbye')
    else:
        print('Please enter one of 1,2,3 or 4')
# Out:
# Enter your choice : 3
# View the to do items
# Enter your choice : 4
# Goodbye

# %%
user_input = 'random'

def show_menu():
    print('Menu:')
    print('1. Add an item')
    print('2. Mark as done')
    print('3. View items')
    print('4. Exit')

while user_input != '4':

    show_menu()
    user_input = input('Enter your choice : ')

    if user_input == '1':
        print('Add an item')
    elif user_input == '2':
        print('Mark as done')
    elif user_input == '3':
        print('View the to do items')
    elif user_input == '4':
        print('Goodbye')
    else:
        print('Please enter one of 1,2,3 or 4')
# Out:
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 1
# Add an item
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 2
# Mark as done
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 3
# View the to do items
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 5
# Please enter one of 1,2,3 or 4
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 4
# Goodbye

# %%
user_input = 'random'
data = []


def show_menu():
    print('Menu:')
    print('1. Add an item')
    print('2. Mark as done')
    print('3. View items')
    print('4. Exit')

while user_input != '4':

    show_menu()
    user_input = input('Enter your choice : ')

    if user_input == '1':
        item = input('What is to be done?')
        data.append(item)
        print('Added item', item)
    elif user_input == '2':
        item = input('What is to be marked as done?')
        if item in data:
            data.remove(item)
            print('Removed item:', item)
        else:
            print('Item does not exist in the list')
    elif user_input == '3':
        print('List of to-do items:')
        for item in data:
            print(item)
    elif user_input == '4':
        print('Goodbye')
    else:
        print('Please enter one of 1,2,3 or 4')
# Out:
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 3
# List of to-do items:
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 1
# What is to be done?buy milk
# Added item buy milk
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 1
# What is to be done?buy milk
# Added item buy milk
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 1
# What is to be done?read book
# Added item read book
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 3
# List of to-do items:
# buy milk
# buy milk
# read book
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 2
# What is to be marked as done?buy milk
# Removed item: buy milk
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 3
# List of to-do items:
# buy milk
# read book
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 1
# What is to be done?buy eggs
# Added item buy eggs
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 3
# List of to-do items:
# buy milk
# read book
# buy eggs
# Menu:
# 1. Add an item
# 2. Mark as done
# 3. View items
# 4. Exit
# Enter your choice : 4
# Goodbye

# %%
def print_square_value(numbers):
    for number in numbers:
        if number != 2:
            squared = number * number
            print(squared)

numbers = [1, 2, 3, 4]

print_square_value(numbers)
# Out:
# 1
# 9
# 16
